# %%
import cv2
import mediapipe as mp
import time


class handDetector:
    def __init__(self, mode=False, maxHands=2, detectionCon=0.5, trackCon=0.5):
        self.mode = mode
        self.maxHands = maxHands
        self.detectionCon = float(detectionCon)  # Ensure float
        self.trackCon = float(trackCon)          # Ensure float

        self.mpHands = mp.solutions.hands
        self.hands = self.mpHands.Hands(
            static_image_mode=self.mode,
            max_num_hands=self.maxHands,
            min_detection_confidence=self.detectionCon,
            min_tracking_confidence=self.trackCon
        )
        self.mpDraw = mp.solutions.drawing_utils

    def findHands(self, img, draw=True):
        imgRGB = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
        self.results = self.hands.process(imgRGB)

        if self.results.multi_hand_landmarks:
            for handLms in self.results.multi_hand_landmarks:
                if draw:
                    self.mpDraw.draw_landmarks(img, handLms, self.mpHands.HAND_CONNECTIONS)
        return img

    def findPosition(self, img, handNo=0, draw=True):
        lmList = []
        if self.results.multi_hand_landmarks:
            myHand = self.results.multi_hand_landmarks[handNo]
            for id, lm in enumerate(myHand.landmark):
                h, w, c = img.shape
                cx, cy = int(lm.x * w), int(lm.y * h)
                lmList.append([id, cx, cy])
                if draw:
                    cv2.circle(img, (cx, cy), 15, (255, 0, 255), cv2.FILLED)

        return lmList


def main():
    pTime = 0
    cTime = 0
    cap = cv2.VideoCapture(0)
    detector = handDetector()

    while True:
        success, img = cap.read()
        if not success:
            print("Error: Unable to read video frame.")
            break

        img = detector.findHands(img)
        lmList = detector.findPosition(img)

        if len(lmList) != 0:
            print(f"Landmark 4 position: {lmList[4]}")

        cTime = time.time()
        fps = 1 / (cTime - pTime)
        pTime = cTime

        cv2.putText(img, f"FPS: {int(fps)}", (10, 70), cv2.FONT_HERSHEY_PLAIN, 3, (255, 0, 255), 3)

        cv2.imshow("Image", img)
        if cv2.waitKey(1) & 0xFF == ord('q'):  # Exit on pressing 'q'
            break

    cap.release()
    cv2.destroyAllWindows()


if __name__ == "__main__":
    main()
# Out:
# Landmark 4 position: [4, 339, 233]
# Landmark 4 position: [4, 333, 209]
# Landmark 4 position: [4, 329, 155]
# Landmark 4 position: [4, 327, 152]
# Landmark 4 position: [4, 341, 169]
# Landmark 4 position: [4, 323, 139]
# Landmark 4 position: [4, 326, 142]
# Landmark 4 position: [4, 323, 136]
# Landmark 4 position: [4, 328, 140]
# Landmark 4 position: [4, 318, 134]
# Landmark 4 position: [4, 321, 139]
# Landmark 4 position: [4, 316, 134]
# Landmark 4 position: [4, 311, 137]
# Landmark 4 position: [4, 312, 138]
# Landmark 4 position: [4, 310, 138]
# Landmark 4 position: [4, 310, 142]
# Landmark 4 position: [4, 310, 144]
# Landmark 4 position: [4, 310, 145]
# Landmark 4 position: [4, 310, 146]
# Landmark 4 position: [4, 306, 144]
# Landmark 4 position: [4, 305, 145]
# Landmark 4 position: [4, 310, 160]
# Landmark 4 position: [4, 301, 156]
# Landmark 4 position: [4, 310, 160]
# Landmark 4 position: [4, 384, 272]
# Landmark 4 position: [4, 388, 293]
# Landmark 4 position: [4, 387, 293]
# Landmark 4 position: [4, 384, 308]
# Landmark 4 position: [4, 389, 306]
# Landmark 4 position: [4, 383, 316]
# Landmark 4 position: [4, 386, 316]
# Landmark 4 position: [4, 385, 315]
# Landmark 4 position: [4, 386, 315]
# Landmark 4 position: [4, 387, 318]
# Landmark 4 position: [4, 386, 318]
# Landmark 4 position: [4, 388, 318]
# Landmark 4 position: [4, 390, 317]
# Landmark 4 position: [4, 390, 317]
# Landmark 4 position: [4, 389, 318]
# Landmark 4 position: [4, 390, 317]
# Landmark 4 position: [4, 390, 317]
# Landmark 4 position: [4, 390, 312]
# Landmark 4 position: [4, 387, 309]
# Landmark 4 position: [4, 384, 310]
# Landmark 4 position: [4, 384, 304]
# Landmark 4 position: [4, 384, 304]
# Landmark 4 position: [4, 384, 299]
# Landmark 4 position: [4, 385, 300]
# Landmark 4 position: [4, 386, 297]
# Landmark 4 position: [4, 385, 299]
# Landmark 4 position: [4, 385, 298]
# Landmark 4 position: [4, 383, 300]
# Landmark 4 position: [4, 384, 299]
# Landmark 4 position: [4, 384, 299]
# Landmark 4 position: [4, 383, 299]
# Landmark 4 position: [4, 384, 298]
# Landmark 4 position: [4, 383, 297]
# Landmark 4 position: [4, 383, 298]
# Landmark 4 position: [4, 382, 294]
# Landmark 4 position: [4, 380, 295]
# Landmark 4 position: [4, 381, 294]
# Landmark 4 position: [4, 379, 295]
# Landmark 4 position: [4, 379, 294]
# Landmark 4 position: [4, 380, 292]
# Landmark 4 position: [4, 378, 294]
# Landmark 4 position: [4, 378, 294]
# Landmark 4 position: [4, 378, 294]
# Landmark 4 position: [4, 378, 295]
# Landmark 4 position: [4, 379, 295]
# Landmark 4 position: [4, 380, 293]
# Landmark 4 position: [4, 381, 292]
# Landmark 4 position: [4, 381, 293]
# Landmark 4 position: [4, 380, 293]
# Landmark 4 position: [4, 380, 293]
# Landmark 4 position: [4, 381, 292]
# Landmark 4 position: [4, 383, 292]
# Landmark 4 position: [4, 384, 292]
# Landmark 4 position: [4, 383, 292]
# Landmark 4 position: [4, 383, 293]
# Landmark 4 position: [4, 383, 293]
# Landmark 4 position: [4, 385, 291]
# Landmark 4 position: [4, 385, 292]
# Landmark 4 position: [4, 385, 292]
# Landmark 4 position: [4, 386, 292]
# Landmark 4 position: [4, 385, 292]
# Landmark 4 position: [4, 387, 291]
# Landmark 4 position: [4, 385, 292]
# Landmark 4 position: [4, 385, 291]
# Landmark 4 position: [4, 385, 290]
# Landmark 4 position: [4, 385, 290]
# Landmark 4 position: [4, 385, 289]
# Landmark 4 position: [4, 385, 289]
# Landmark 4 position: [4, 384, 289]
# Landmark 4 position: [4, 383, 288]
# Landmark 4 position: [4, 384, 288]
# Landmark 4 position: [4, 384, 288]
# Landmark 4 position: [4, 384, 290]
# Landmark 4 position: [4, 384, 290]
# Landmark 4 position: [4, 385, 291]
# Landmark 4 position: [4, 382, 295]
# Landmark 4 position: [4, 383, 295]
# Landmark 4 position: [4, 384, 294]
# Landmark 4 position: [4, 384, 295]
# Landmark 4 position: [4, 384, 295]
# Landmark 4 position: [4, 384, 293]
# Landmark 4 position: [4, 384, 293]
# Landmark 4 position: [4, 385, 291]
# Landmark 4 position: [4, 385, 291]
# Landmark 4 position: [4, 384, 291]
# Landmark 4 position: [4, 384, 291]
# Landmark 4 position: [4, 384, 289]
# Landmark 4 position: [4, 382, 289]
# Landmark 4 position: [4, 382, 289]
# Landmark 4 position: [4, 381, 290]
# Landmark 4 position: [4, 382, 289]
# Landmark 4 position: [4, 383, 289]
# Landmark 4 position: [4, 382, 288]
# Landmark 4 position: [4, 381, 288]
# Landmark 4 position: [4, 381, 288]
# Landmark 4 position: [4, 381, 287]
# Landmark 4 position: [4, 381, 288]
# Landmark 4 position: [4, 381, 287]
# Landmark 4 position: [4, 381, 287]
# Landmark 4 position: [4, 381, 287]
# Landmark 4 position: [4, 381, 286]
# Landmark 4 position: [4, 382, 287]
# Landmark 4 position: [4, 384, 286]
# Landmark 4 position: [4, 383, 287]
# Landmark 4 position: [4, 384, 285]
# Landmark 4 position: [4, 384, 285]
# Landmark 4 position: [4, 387, 283]
# Landmark 4 position: [4, 387, 285]
# Landmark 4 position: [4, 388, 283]
# Landmark 4 position: [4, 388, 285]
# Landmark 4 position: [4, 391, 284]
# Landmark 4 position: [4, 390, 285]
# Landmark 4 position: [4, 391, 282]
# Landmark 4 position: [4, 390, 284]
# Landmark 4 position: [4, 391, 284]
# Landmark 4 position: [4, 390, 284]
# Landmark 4 position: [4, 391, 283]
# Landmark 4 position: [4, 391, 283]
# Landmark 4 position: [4, 392, 283]
# Landmark 4 position: [4, 392, 284]
# Landmark 4 position: [4, 393, 284]
# Landmark 4 position: [4, 393, 284]
# Landmark 4 position: [4, 397, 284]
# Landmark 4 position: [4, 395, 284]
# Landmark 4 position: [4, 397, 285]
# Landmark 4 position: [4, 395, 286]
# Landmark 4 position: [4, 396, 286]
# Landmark 4 position: [4, 397, 287]
# Landmark 4 position: [4, 397, 287]
# Landmark 4 position: [4, 397, 287]
# Landmark 4 position: [4, 397, 287]
# Landmark 4 position: [4, 396, 286]
# Landmark 4 position: [4, 396, 286]
# Landmark 4 position: [4, 396, 286]
# Landmark 4 position: [4, 395, 286]
# Landmark 4 position: [4, 397, 286]
# Landmark 4 position: [4, 396, 287]
# Landmark 4 position: [4, 396, 287]
# Landmark 4 position: [4, 398, 285]
# Landmark 4 position: [4, 398, 286]
# Landmark 4 position: [4, 398, 286]
# Landmark 4 position: [4, 398, 286]
# Landmark 4 position: [4, 398, 285]
# Landmark 4 position: [4, 398, 285]
# Landmark 4 position: [4, 399, 286]
# Landmark 4 position: [4, 398, 286]
# Landmark 4 position: [4, 399, 286]
# Landmark 4 position: [4, 398, 287]
# Landmark 4 position: [4, 399, 286]
# Landmark 4 position: [4, 398, 286]
# Landmark 4 position: [4, 400, 286]
# Landmark 4 position: [4, 398, 286]
# Landmark 4 position: [4, 400, 285]
# Landmark 4 position: [4, 399, 285]
# Landmark 4 position: [4, 399, 285]
# Landmark 4 position: [4, 400, 285]
# Landmark 4 position: [4, 399, 286]
# Landmark 4 position: [4, 399, 286]
# Landmark 4 position: [4, 401, 285]
# Landmark 4 position: [4, 399, 286]
# Landmark 4 position: [4, 399, 285]
# Landmark 4 position: [4, 399, 285]
# Landmark 4 position: [4, 399, 287]
# Landmark 4 position: [4, 396, 287]
# Landmark 4 position: [4, 398, 288]
# Landmark 4 position: [4, 397, 287]
# Landmark 4 position: [4, 397, 288]
# Landmark 4 position: [4, 396, 287]
# Landmark 4 position: [4, 396, 288]
# Landmark 4 position: [4, 397, 287]
# Landmark 4 position: [4, 396, 288]
# Landmark 4 position: [4, 397, 288]
# Landmark 4 position: [4, 396, 287]
# Landmark 4 position: [4, 396, 287]
# Landmark 4 position: [4, 397, 287]
# Landmark 4 position: [4, 395, 287]
# Landmark 4 position: [4, 395, 287]
# Landmark 4 position: [4, 393, 289]
# Landmark 4 position: [4, 390, 288]
# Landmark 4 position: [4, 361, 288]
# Landmark 4 position: [4, 342, 304]
# Landmark 4 position: [4, 344, 305]
# Landmark 4 position: [4, 326, 313]
# Landmark 4 position: [4, 325, 314]
# Landmark 4 position: [4, 376, 403]
# Landmark 4 position: [4, 385, 397]
# Landmark 4 position: [4, 385, 401]
# Landmark 4 position: [4, 388, 402]
# Landmark 4 position: [4, 390, 404]
# Landmark 4 position: [4, 398, 403]
# Landmark 4 position: [4, 401, 401]
# Landmark 4 position: [4, 408, 401]
# Landmark 4 position: [4, 406, 403]
